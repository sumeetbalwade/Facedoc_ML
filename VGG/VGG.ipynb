# %%
from keras.applications.vgg16 import VGG16
model = VGG16(weights='imagenet')
print(model.summary)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 349s 1us/step
# <bound method Network.summary of <keras.engine.training.Model object at 0x0000023DF6A94D08>>

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input,decode_predictions
import numpy as np

img_path = r'C:\Users\omkar\OneDrive\Desktop\photo.jpeg'
img = image.load_img(img_path,color_mode='rgb', target_size=(224,224))
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x23DE46681C8>

# %%
x = image.img_to_array(img)
x.shape
# Out:
# (224, 224, 3)

# %%
x = np.expand_dims(x, axis=0)
x.shape
# Out:
# (1, 224, 224, 3)

# %%
x= preprocess_input(x)
features = model.predict(x)
p = decode_predictions(features)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 40960/35363 [==================================] - 0s 0us/step

# %%
p
# Out:
# [[('n04370456', 'sweatshirt', 0.17854792),
#   ('n03595614', 'jersey', 0.08221605),
#   ('n02730930', 'apron', 0.03559761),
#   ('n03141823', 'crutch', 0.028376412),
#   ('n04311174', 'steel_drum', 0.02786199)]]

# %%
img_path = r'D:\DOWNLOADS\gd.jpg'
img = image.load_img(img_path,color_mode='rgb', target_size=(224,224))
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x23E5BB5C948>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x.shape
# Out:
# (1, 224, 224, 3)

# %%
x= preprocess_input(x)
features = model.predict(x)
p = decode_predictions(features)

# %%
p
# Out:
# [[('n02099601', 'golden_retriever', 0.79009134),
#   ('n02099712', 'Labrador_retriever', 0.022413548),
#   ('n02100583', 'vizsla', 0.021914393),
#   ('n02091831', 'Saluki', 0.02134923),
#   ('n02090379', 'redbone', 0.013894252)]]

# %%
img_path = r'C:\Users\omkar\OneDrive\Desktop\AB.jpg'
img = image.load_img(img_path,color_mode='rgb', target_size=(224,224))
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x23E5D049C48>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x.shape
# Out:
# (1, 224, 224, 3)

# %%
x= preprocess_input(x)
features = model.predict(x)
p = decode_predictions(features)

# %%
p
# Out:
# [[('n03724870', 'mask', 0.49020556),
#   ('n04522168', 'vase', 0.16111426),
#   ('n03544143', 'hourglass', 0.034212086),
#   ('n04229816', 'ski_mask', 0.031005412),
#   ('n04133789', 'sandal', 0.0292861)]]

# %%
from keras.applications.vgg16 import VGG16
model = VGG16()
print(model.summary)
# Out:
# <bound method Network.summary of <keras.engine.training.Model object at 0x0000023EE220BE88>>
